# %%
import pandas as pd
import numpy as np

# %%
# %pwd
# Out:
# '/home/shared/code'

# %%
delay_features = [
    'DayOfWeek',
    'FlightDate',
    'IATA_CODE_Reporting_Airline',
    'Tail_Number',
    'Flight_Number_Reporting_Airline',
    'OriginAirportID',
    'Origin',
    'OriginState',
    'DestAirportID',
    'Dest',
    'DestState',
    'CRSDepTime',
    'DepTime',
    'DepDelayMinutes',
    'CRSArrTime',
    'ArrTime',
    'ArrDelayMinutes',
    'Cancelled',
    'CancellationCode',
    'Diverted',
    'CarrierDelay',
    'WeatherDelay',
    'NASDelay',
    'SecurityDelay',
    'LateAircraftDelay'
]

dtypes = {
    'DayOfWeek':                       int,
    'FlightDate':                      'string',
    'IATA_CODE_Reporting_Airline':     'string',
    'Tail_Number':                     'string',
    'Flight_Number_Reporting_Airline': int,
    'OriginAirportID':                 int,
    'Origin':                          'string',
    'OriginState':                     'string',
    'DestAirportID':                   int,
    'Dest':                            'string',
    'DestState':                       'string',
    'CRSDepTime':                      int,
    'DepTime':                         np.float64,
    'DepDelayMinutes':                 np.float64,
    'CRSArrTime':                      int,
    'ArrTime':                         np.float64,
    'ArrDelayMinutes':                 np.float64,
    'Cancelled':                       int,
    'CancellationCode':                'string',
    'Diverted':                        int,
    'CarrierDelay':                    np.float64,
    'WeatherDelay':                    np.float64,
    'NASDelay':                        np.float64,
    'SecurityDelay':                   np.float64,
    'LateAircraftDelay':               np.float64
}

# %%
add_header = True
chunksize = 10**5

for chunk in pd.read_csv('data/airline-performance/aperf-2022.csv', chunksize=chunksize, usecols=delay_features, dtype=dtypes):
    chunk.to_csv('data/airline-performance/aperf-2022-dropped.csv', mode='a', index=False, header=add_header)
    if add_header:
        # The header should not be printed more than one
        add_header = False

# %%
df = pd.read_csv('data/airline-performance/aperf-2022-dropped.csv', dtype=dtypes)
df
# Out:
#          DayOfWeek  FlightDate IATA_CODE_Reporting_Airline Tail_Number  \
# 0                5  2022-01-14                          YX      N119HQ
# 1                6  2022-01-15                          YX      N122HQ
# 2                7  2022-01-16                          YX      N412YX
# 3                1  2022-01-17                          YX      N405YX
# 4                2  2022-01-18                          YX      N420YX
# ...            ...         ...                         ...         ...
# 6729120          3  2022-12-21                          NK      N623NK
# 6729121          4  2022-12-22                          NK      N623NK
# 6729122          5  2022-12-23                          NK      N692NK
# 6729123          6  2022-12-24                          NK      N622NK
# 6729124          7  2022-12-25                          NK      N622NK
#
#          Flight_Number_Reporting_Airline  OriginAirportID Origin OriginState  \
# ...

# %%
df = df.loc[(df['DepDelayMinutes'] > 0.0) | (df['ArrDelayMinutes'] > 0.0)]
df
# Out:
#          DayOfWeek  FlightDate IATA_CODE_Reporting_Airline Tail_Number  \
# 0                5  2022-01-14                          YX      N119HQ
# 3                1  2022-01-17                          YX      N405YX
# 6                4  2022-01-20                          YX      N116HQ
# 7                5  2022-01-21                          YX      N419YX
# 10               1  2022-01-24                          YX      N128HQ
# ...            ...         ...                         ...         ...
# 6729106          3  2022-12-07                          NK      N698NK
# 6729110          7  2022-12-11                          NK      N649NK
# 6729118          1  2022-12-19                          NK      N611NK
# 6729119          2  2022-12-20                          NK      N614NK
# 6729122          5  2022-12-23                          NK      N692NK
#
#          Flight_Number_Reporting_Airline  OriginAirportID Origin OriginState  \
# ...

# %%
bird_df = pd.read_csv('data/bird-strike/bird-strike.csv')
bird_df
# Out:
# /tmp/ipykernel_5972/1820331372.py:1: DtypeWarning: Columns (17,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   bird_df = pd.read_csv('data/bird-strike/bird-strike.csv')
#         INDEX_NR      INCIDENT_DATE  INCIDENT_MONTH  INCIDENT_YEAR   TIME  \
# 0         608242  06/22/96 00:00:00               6           1996    NaN
# 1         608243  06/26/96 00:00:00               6           1996    NaN
# 2         608244  07/01/96 00:00:00               7           1996    NaN
# 3         608245  07/01/96 00:00:00               7           1996    NaN
# 4         608246  07/01/96 00:00:00               7           1996    NaN
# ...          ...                ...             ...            ...    ...
# 288598   1471167  08/25/23 00:00:00               8           2023  01:22
# 288599   1471168  08/25/23 00:00:00               8           2023  09:20
# 288600   1471170  08/25/23 00:00:00               8           2023  23:45
# ...

# %%
print(bird_df.iloc[235198])
# Out:
# INDEX_NR                     1156816
# INCIDENT_DATE      09/17/21 00:00:00
# INCIDENT_MONTH                     9
# INCIDENT_YEAR                   2021
# TIME                           18:03
#                          ...
# SOURCE             FAA Form 5200-7-E
# PERSON            Airport Operations
# LUPDATE            10/13/21 00:00:00
# TRANSFER                           0
# DISTANCE                         NaN
# Name: 235198, Length: 100, dtype: object

# %%
bird_df = bird_df.loc[bird_df['INCIDENT_YEAR']]
# Out:
# 0
