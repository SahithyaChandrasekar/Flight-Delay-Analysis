# %%
import pandas as pd

# %%
# %pwd
# Out:
# '/home/shared/code'

# %%
df = pd.read_csv('data/airline-performance/individual/aperf-2017-01.csv')
# Out:
# /var/tmp/ipykernel_199970/370083937.py:1: DtypeWarning: Columns (48,77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/airline-performance/individual/aperf-2017-01.csv')

# %%
df.dtypes
# Out:
# Year                  int64
# Quarter               int64
# Month                 int64
# DayofMonth            int64
# DayOfWeek             int64
#                      ...
# Div5TotalGTime      float64
# Div5LongestGTime    float64
# Div5WheelsOff       float64
# Div5TailNum         float64
# Unnamed: 109        float64
# Length: 110, dtype: object

# %% [raw]
# df.isnull().sum()

# %%
df.DestState.unique()
# Out:
# array(['CA', 'NY', 'HI', 'TX', 'FL', 'NV', 'MA', 'IL', 'MI', 'WA', 'MO',
#        'VA', 'TN', 'CO', 'OR', 'UT', 'NC', 'AZ', 'NJ', 'MD', 'PA', 'GA',
#        'MN', 'OK', 'PR', 'VI', 'IN', 'CT', 'OH', 'LA', 'WI', 'KY', 'RI',
#        'SC', 'AK', 'NE', 'NM', 'ME', 'KS', 'ND', 'MS', 'AR', 'WY', 'MT',
#        'AL', 'IA', 'NH', 'SD', 'ID', 'WV', 'VT', 'TT'], dtype=object)

# %%
df.count()
# Out:
# Year                450017
# Quarter             450017
# Month               450017
# DayofMonth          450017
# DayOfWeek           450017
#                      ...
# Div5TotalGTime           0
# Div5LongestGTime         0
# Div5WheelsOff            0
# Div5TailNum              0
# Unnamed: 109             0
# Length: 110, dtype: int64

# %%
# Out:
#          Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0       False    False  False       False      False       False
# 1       False    False  False       False      False       False
# 2       False    False  False       False      False       False
# 3       False    False  False       False      False       False
# 4       False    False  False       False      False       False
# ...       ...      ...    ...         ...        ...         ...
# 450012  False    False  False       False      False       False
# 450013  False    False  False       False      False       False
# 450014  False    False  False       False      False       False
# 450015  False    False  False       False      False       False
# 450016  False    False  False       False      False       False
#
#         Reporting_Airline  DOT_ID_Reporting_Airline  \
# 0                   False                     False
# 1                   False                     False
# ...

# %%
df.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate Reporting_Airline  \
# 0  2017        1      1           1          7  2017-01-01                AA
# 1  2017        1      1           2          1  2017-01-02                AA
# 2  2017        1      1           3          2  2017-01-03                AA
# 3  2017        1      1           4          3  2017-01-04                AA
# 4  2017        1      1           5          4  2017-01-05                AA
#
#    DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline Tail_Number  ...  \
# 0                     19805                          AA      N787AA  ...
# 1                     19805                          AA      N788AA  ...
# 2                     19805                          AA      N783AA  ...
# 3                     19805                          AA      N799AA  ...
# 4                     19805                          AA      N788AA  ...
#
# ...

# %%
df.drop
